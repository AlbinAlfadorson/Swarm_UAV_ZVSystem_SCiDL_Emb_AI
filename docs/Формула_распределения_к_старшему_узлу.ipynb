# %% [markdown]
# # Формула распределения данных к старшему узлу (королеве)## Основное уравнение$$Q = \sum_{i=1}^{N} W_i \cdot \mathrm{In}(i)$$где:- $N$ — количество дронов- $\mathrm{In}(i)$ — входные данные дрона $i$- $W_i$ — вес дрона $i$- $Q$ — данные королевы## AMPL реализация```amplset Drones;param In {i in Drones};param W {i in Drones};var Q;subject to Queen_Input: Q = sum{i in Drones} (W[i] * In[i]);display Q;```
